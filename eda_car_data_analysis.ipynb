# %% [markdown]
# <a href="https://colab.research.google.com/github/wmaldonadodsa/analise-de-dados-e-boas-praticas/blob/main/eda_car_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MVP de Análise de Dados e Boas Práticas
#
# ## Waldemar Maldonado
# [![logo-puc-rio-svg](https://github.com/wmaldonadodsa/analise-de-dados-e-boas-praticas/assets/153657974/e0a536bb-2d10-4de2-8048-882d71550780)  *Pós em Ciência de Dados e Analytics - 2023*](https://pucrio.grupoa.education/plataforma/)
#
# ![image](https://github.com/wmaldonadodsa/analise-de-dados-e-boas-praticas/assets/153657974/c7d38ca7-717d-4cbc-b8c3-7e193334e143)

# %% [markdown]
# ## 1. Definição do Problema

# %% [markdown]
# O dataset CAR DEKHO. É um conjunto de dados popular usado para análises e projetos de machine learning relacionados ao mercado de carros usados. Este dataset geralmente inclui várias características de carros usados, como:
#
# 1. **Marca e Modelo do Carro**: Informações sobre a marca e o modelo do carro.
# 2. **Ano de Fabricação**: O ano em que o carro foi fabricado.
# 3. **Preço de Venda**: O preço pelo qual o carro está sendo vendido.
# 4. **Kilometragem**: A quilometragem percorrida pelo carro.
# 5. **Tipo de Combustível**: Se o carro é movido a diesel, gasolina, GNV, etc.
# 6. **Tipo de Transmissão**: Manual ou automática.
# 7. **Donos Anteriores**: Número de proprietários anteriores do carro.
#
# Esses dados são frequentemente utilizados para criar modelos preditivos, como estimar o preço de um carro usado com base em suas características. Além disso, análises exploratórias desse dataset podem fornecer insights valiosos sobre o mercado de carros usados, como tendências de preços, preferências de marca/modelo, impacto da quilometragem no valor do carro, entre outros.
#
# O dataset CAR DEKHO é uma ótima ferramenta para quem está aprendendo ciência de dados, pois oferece um conjunto de dados do mundo real com o qual é possível trabalhar, testar hipóteses e construir modelos de machine learning.

# %% [markdown]
# # <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">⭐️ Análise de Dados de Carros ⭐️</p>
#
# <p style="text-align:center; ">
# <img src="https://www.hareketligifler.net/data/media/67/araba-hareketli-resim-0321.gif" style='width: 600px; height: 300px;'>
# </p>
#
# <p style="text-align:justify; ">
#  <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">"Estes dados foram coletados do 'Car Dekho'. Os seguintes detalhes dos carros estão incluídos no dataset:
#
#
# 1) Nome do carro
#
# 2) Ano
#
# 3) Preço de venda
#
# 4) Quilômetros rodados
#
# 5) Combustível
#
# 6) Tipo de vendedor
#
# 7) Transmissão
#
# 8) Proprietário
#
# </p>
#
#
#    <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist"></div>
#
#
#  <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">⭐️ ÍNDICE ⭐️</p>
#
#
# * [1. Importando Bibliotecas](#1)
#
# * [2. Carregando o Dataset](#2)
#
# * [3. Explorando Algumas Informações Sobre o Dataset](#3)
#
# * [4. Visualização de Dados](#4)
#
# * [5. Resultado](#5)
#
# * [6. Mensagem do Autor](#6)

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Importando Bibliotecas</p>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.graph_objs as go
import plotly.express as px

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Carregando o Dataset</p>

# %%
url = 'https://raw.githubusercontent.com/wmaldonadodsa/analise-de-dados-e-boas-praticas/main/CAR%20DETAILS%20FROM%20CAR%20DEKHO.csv'

# Informa o cabeçalho das colunas
colunas = ['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission', 'owner']

# Lê o arquivo utilizando as colunas informadas
df = pd.read_csv(url, names=colunas, skiprows=1, delimiter=',')

df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Explorando Algumas Informações Sobre o Dataset</p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Aqui está a contagem de linhas e o tipo de cada coluna
# </p>
# </div>

# %%
df.shape
# Out:
# (4340, 8)

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">.
# </p>Este código nos fornece a informação das colunas e linhas do dataset
# </div>

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Este código nos mostra alguns valores de valores numéricos, como média, desvio padrão, mínimo, máximo.
# </p>
# </div>

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Este código nos fornece o número de valores nulos no dataset</p>
# </div>

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Este código nos fornece o nome das colunas no dataset
# </p>
# </div>

# %%
df["name_2"] = df.name.apply(lambda x : ' '.join(x.split(' ')[:1]))
df['name_2']
# Out:
# 0        Maruti
# 1        Maruti
# 2       Hyundai
# 3        Datsun
# 4         Honda
#          ...
# 4335    Hyundai
# 4336    Hyundai
# 4337     Maruti
# 4338    Hyundai
# 4339    Renault
# Name: name_2, Length: 4340, dtype: object

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Esta linha de código é o processo de separação para identificar a marca dos modelos de carros na coluna chamada 'nome'. A coluna chamada 'nome' é então salva como uma nova variável 'name_2'".
# </p>
# </div>

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Visualização de Dados</p>

# %%
df.name_2.value_counts()
# Out:
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Fiat               37
# Datsun             37
# Mercedes-Benz      35
# Jaguar              6
# Mitsubishi          6
# Land                5
# Volvo               4
# Ambassador          4
# Jeep                3
# MG                  2
# OpelCorsa           2
# Daewoo              1
# Force               1
# Isuzu               1
# Kia                 1
# Name: name_2, dtype: int64

# %%
sns.countplot(data=df,x="name_2",palette="CMRmap")
plt.xticks(rotation=90)
plt.xlabel("Nome",fontsize=10,color="black")
plt.ylabel("Nome",fontsize=10,color="black")
plt.title("Contagem por Nome",color="black")
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">The most common car model is the Maruti.
#
# INFORMATION: Maruti Suzuki India Limited, formerly known as Maruti Udyog Limited, is an Indian automobile manufacturer, based in New Delhi.
#
# </p>
# </div>

# %%
labels = df["name_2"][:30].value_counts().index
sizes = df["name_2"][:30].value_counts()
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99',"pink","yellow"]
plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%',colors=colors,shadow=True, startangle=45)
plt.title('nome',color = 'red',fontsize = 15)
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">O modelo de carro mais comum é o Maruti. Ele é mostrado com uma tabela em formato de gráfico de pizza nesta tabela.
# </p>
# </div>

# %%
from wordcloud import WordCloud, STOPWORDS

text = ' '.join(df['name_2'])

plt.rcParams['figure.figsize'] = (12,12)
wordcloud = WordCloud(background_color = 'black',colormap='vlag', width = 1200,  height = 1200, max_words = 121).generate(text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">"Novamente, o tipo de carro mais comum foi o Maruti, seguido pelo Hyundai. Isso é ilustrado com um gráfico de nuvem de palavras.
# </p>
# </div>

# %%
df.year.value_counts()
# Out:
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: year, dtype: int64

# %%
sns.countplot(data=df,x="year",palette="icefire")
plt.xticks(rotation=90)
plt.xlabel("Ano",fontsize=10,color="RED")
plt.ylabel("Qtd",fontsize=10,color="RED")
plt.title("Ano Qtd",color="RED")
plt.show()

# %%
labels = df["year"][:40].value_counts().index
sizes = df["year"][:40].value_counts()
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99',"pink","yellow"]
plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%',colors=colors,shadow=True, startangle=45)
plt.title('Ano',color = 'red',fontsize = 15)
plt.show()

# %%
df.fuel.value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Nesta tabela, observa-se que o tipo de combustível mais comum é o diesel, seguido pela gasolina
# </div>

# %%
labels = df["fuel"].value_counts().index
sizes = df["fuel"].value_counts()
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99',"pink","yellow"]
plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.f%%',colors=colors,shadow=True, startangle=9)
plt.title('fuel',color = 'blue',fontsize = 15)
plt.show()

# %%
df.seller_type.value_counts()
# Out:
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: seller_type, dtype: int64

# %%
sns.countplot(data=df,x="seller_type",palette="pink")
plt.xlabel("Tipo de vendedor",fontsize=10,color="brown")
plt.ylabel("Qtd",fontsize=10,color="brown")
plt.title("Tipo de vendedor Qtd",color="brown")
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Esta é uma tabela mostrando onde as vendas são realizadas. As vendas individuais são as mais altas.
# </p>
# </div>

# %%
plt.figure(figsize=(14, 7))
labels=["Trustmark Dealer","Dealer","İndividual"]
plt.pie(df['seller_type'].value_counts().sort_values(),labels=labels,explode=[0,0,0],
        autopct='%1.2f%%',colors=['gray','lightgreen',"orange"], startangle=60,shadow=True)
plt.title("Tipo de vendedor Qtd",color="orange")
plt.axis('equal')
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Este é o gráfico de pizza mostrando onde as vendas foram realizadas. As vendas individuais são as mais altas.
# </p>
# </div>

# %%
df.transmission.value_counts()
# Out:
# Manual       3892
# Automatic     448
# Name: transmission, dtype: int64

# %%
sns.countplot(data=df,x="transmission",palette="Spectral")
plt.xlabel("Transmissão",fontsize=10,color="GREEN")
plt.ylabel("Qtd",fontsize=10,color="GREEN")
plt.title("Transmissão Qtd",color="GREEN")
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">É o gráfico que mostra se os carros são manuais ou automáticos.
#  Most are manual cars
# </p>
# </div>

# %%
plt.figure(figsize=(14, 7))
labels=['Automatico', 'Manual']
plt.pie(df['transmission'].value_counts().sort_values(),labels=labels,explode=[0.1,0.1],
        autopct='%1.2f%%',colors=['lightgray','cyan'], startangle=90)
plt.title('Transmissão')
plt.axis('equal')
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">É o gráfico que mostra se os carros são manuais ou automáticos. Gráfico de pizza mostrando que a maioria deles são carros manuais.
# </p>
# </div>

# %%
df.owner.value_counts()
# Out:
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: owner, dtype: int64

# %%
sns.countplot(data=df,x="owner",palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Proprietário",fontsize=10,color="purple")
plt.ylabel("Qtd",fontsize=10,color="purple")
plt.title("Proprietário Qtd",color="purple")
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Este gráfico nos mostra que os vendedores estão vendendo mais carros de primeira mão
# </p>
# </div>

# %%
labels = df["owner"].value_counts().index
sizes = df["owner"].value_counts()
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99',"pink","yellow"]
plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%',colors=colors,shadow=True, startangle=905)
plt.title('Proprietário',color = 'red',fontsize = 15)
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Este gráfico de pizza nos mostra que os vendedores estão vendendo mais carros de primeira mão
# </p>
# </div>

# %%
sns.histplot(data=df, x="year", hue="transmission")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">É o gráfico de histograma mostrando a distribuição de carros manuais e automáticos por anos.
# </p>
# </div>

# %%
sns.violinplot(data=df, x="year", y="fuel",hue="transmission")
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">É o gráfico de violino mostrando a distribuição de carros manuais e automáticos por anos.
# </p>
# </div>

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner   name_2
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %%
df1 = df.groupby(["transmission","fuel","name_2"],as_index=False)[['selling_price']].median().rename(columns={'selling_price':'price'})
fig = px.treemap(df1, path = [px.Constant("all"), "transmission","fuel","name_2"],
                 values   ='price', color='name_2',
                 color_discrete_map={'(?)':'lightgrey', 'Lunch':'gold', 'Dinner':'darkblue'})
fig.update_layout(margin  = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pd.crosstab(df["name_2"], df["transmission"]).plot(kind="bar", figsize=(10, 6), color=["blue","red"], title="name and transmission ")
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Esta tabela é uma tabela cruzada mostrando a distribuição automática e manual dos modelos de carros.
# </p>
# </div>

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(10,10))
plt.title("happiness rate of continents by year")
sns.set(font_scale=1)
plt.xticks(rotation=90)
sns.barplot(data=df, x="name_2", y="km_driven",hue="transmission",palette="gist_rainbow")
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Esta tabela é um gráfico de barras do consumo de combustível dos modelos de carros.
# </p>
# </div>

# %%
fig, ax = plt.subplots(figsize=(12,12))
corr1   = df.corr()
sns.heatmap(corr1, ax=ax, annot=True, cmap='terrain_r', fmt=".2f", linewidths=.5, vmin=-1, vmax=1)
# Out:
# <ipython-input-33-2af0fa9ce383>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Esta tabela é um gráfico de correlação de valores numéricos.
# </p>
# </div>

# %%
pd.crosstab(df["name_2"], df["owner"]).plot(kind="bar", figsize=(10, 6), color=["purple","orange","lightgreen","blue","red"], title="name and owner ")
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Esta tabela é um gráfico que mostra como os modelos de carros são classificados como primeiro, segundo, terceiro, quarto e acima, ou veículo de teste
# </p>
# </div>

# %%
joint_data=df.sort_values(by='year', ascending=False)

top_rated=joint_data[:2500]
fig =px.sunburst(
    top_rated,
    path=['year',"name_2"],
    values='year',
    color='year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
joint_data=df.sort_values(by='year', ascending=False)

top_rated=joint_data[2500:]
fig =px.sunburst(
    top_rated,
    path=['year',"name_2"],
    values='year',
    color='year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.strip(df, x='year', y='name_2', color='year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
f, ax = plt.subplots(figsize=(20,8))
sns.boxplot(x=df["name_2"].values, y = df["km_driven"].values,palette="twilight",ax=ax)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <div style="color:yellow;
#            display:fill;
#            border-radius:25px;
#            background-color:#27948b;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#            color:#e7d954;">Esta tabela é um gráfico de caixa por 'name_2' e quilômetros.
# </p>
# </div>

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Resultado</p>

# %% [markdown]
# # O carro mais vendido é o Maruti. Em seguida, vem a Hyundai.
# # Os carros costumam ser manuais.
# # De acordo com os dados,  os veículos geralmente são vendidos de primeira mão, seguidos pelos veículos de segunda mão.
# # A maioria das vendas é feita individualmente.
# # A maioria das vendas foi feita em 2017.
# # Com base nesses dados, podemos dizer que houve muita produção em 2017.

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#27948b;margin:0;color:#e7d954;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Mensagem do autor: </p>

# %% [markdown]
# <p style="background-color:#27948b;font-family:newtimeroman;color:#e7d954;font-size:130%;text-align:center;border-radius:20px 20px;">  ⭐️ Muito gratificante e enriquecedor de minha aprendizagem. Todo o conteúdo é muito aplicado no mercado. Agradeço muito o compartilhar desse conhecimento.⭐️</p>
